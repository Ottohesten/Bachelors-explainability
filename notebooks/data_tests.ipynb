# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn

import mne

# %%
raw = mne.io.read_raw_edf(r'data\tuh_eeg_artifact_TUAR\edf\01_tcp_ar\aaaaaaju_s005_t000.edf')
# Out:
# Extracting EDF parameters from c:\Users\Otto\OneDrive - Danmarks Tekniske Universitet\DTU\Kurser\Bachelors\Bachelors-explainability\data\tuh_eeg_artifact_TUAR\edf\01_tcp_ar\aaaaaaju_s005_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...

# %%
raw.info
# Out:
# <Info | 8 non-empty values
#  bads: []
#  ch_names: EEG FP1-REF, EEG FP2-REF, EEG F3-REF, EEG F4-REF, EEG C3-REF, ...
#  chs: 36 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 125.0 Hz
#  meas_date: 2010-01-01 00:00:00 UTC
#  nchan: 36
#  projs: []
#  sfreq: 250.0 Hz
#  subject_info: 3 items (dict)
# >
