# %%
import h5py
import mne

# %%
data_dir = "data/preprocessed_downstream/mmidb_noica_5.0_combined/"
# data_dir = "data/preprocessed_downstream/mmidb_noica_5.0/"
file_name = "combined_00000.hdf5"
# file_name = "data_1.hdf5"

file = h5py.File(data_dir + file_name, 'r')

# %%
file.keys()
# Out:
# <KeysViewHDF5 ['data', 'file_idxs', 'labels', 'sessions_labels', 'time_slices']>

# %%
# file["sessions_labels"]
# file["time_slices"]
# Out:
# <HDF5 dataset "time_slices": shape (18109, 2), type "<f4">

# %%
# open raw edf file
raw = mne.io.read_raw_edf("data/mmidb/files/s003/s003R01.edf")
# Out:
# Extracting EDF parameters from c:\Users\Otto\repos\Bachelors-explainability\data\mmidb\files\s003\s003R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...

# %%
# get filename of the raw file
raw
# Out:
# <RawEDF | s003R01.edf, 64 x 9760 (61.0 s), ~54 kB, data not loaded>
