# %%
import mne
import pandas as pd
import os
from glob import glob

from utils import process_TUSZ_edf

# %% [markdown]
# # Test load of edf file

# %%
raw_edf_file_path = "/nobackup/tsal-tmp/tuh_eeg_seizure/v2.0.0/edf/train/aaaaaaac/s001_2002_12_23/02_tcp_le/aaaaaaac_s001_t000.edf"


raw = mne.io.read_raw_edf(raw_edf_file_path, preload=True)
raw
# Out:
# Extracting EDF parameters from /nobackup/tsal-tmp/tuh_eeg_seizure/v2.0.0/edf/train/aaaaaaac/s001_2002_12_23/02_tcp_le/aaaaaaac_s001_t000.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 75249  =      0.000 ...   300.996 secs...
# <RawEDF | aaaaaaac_s001_t000.edf, 33 x 75250 (301.0 s), ~19.0 MB, data loaded>

# %% [markdown]
# # Load of the annotations csv file

# %%
annot_path = raw_edf_file_path.split(".edf")[0] + ".csv_bi"

# 6 lines of header

annot_df = pd.read_csv(annot_path, sep=",", skiprows=5)
annot_df
# Out:
#   channel  start_time  stop_time label  confidence
# 0    TERM     36.8868   237.2101  seiz         1.0

# %%
annot_df["label"].unique()
# Out:
# array(['seiz'], dtype=object)

# %%
raw_processed = process_TUSZ_edf(raw_edf_file_path)

# %%
raw_processed.annotations
# Out:
# <Annotations | 1 segment: seiz (1)>
