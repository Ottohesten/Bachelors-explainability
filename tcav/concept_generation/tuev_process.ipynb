# %%
import mne
import pandas as pd
import os
from glob import glob
from utils import read_TUH_edf, load_tuev_annotation, process_TUEV_edf

# %%
# raw_edf_file_path = "/nobackup/tsal-tmp/tuh_eeg_events/v2.0.0/edf/train/00000017/00000017_00000001.edf"
# raw_edf_file_path = "/nobackup/tsal-tmp/tuh_eeg_events/v2.0.0/edf/train/00000081/00000081_00000005.edf"
# raw_edf_file_path = "/nobackup/tsal-tmp/tuh_eeg_events/v2.0.0/edf/train/00002996/00002996_00000001.edf"
# raw_edf_file_path = "/nobackup/tsal-tmp/tuh_eeg_events/v2.0.0/edf/train/00002875/00002875_00000007.edf"
# raw_edf_file_path = "/nobackup/tsal-tmp/tuh_eeg_events/v2.0.0/edf/train/00000878/00000878_00000001.edf"
raw_edf_file_path = "/nobackup/tsal-tmp/tuh_eeg_events/v2.0.0/edf/train/00001940/00001940_00000001.edf"

raw_tuh_selected_file_path = "/scratch/agjma/tuh_selected/aaaaaado_s004_t002.edf"

raw = mne.io.read_raw_edf(raw_edf_file_path, preload=True)
raw_tuh_selected = mne.io.read_raw_edf(raw_tuh_selected_file_path, preload=True)
# Out:
# Extracting EDF parameters from /nobackup/tsal-tmp/tuh_eeg_events/v2.0.0/edf/train/00001940/00001940_00000001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 305749  =      0.000 ...  1222.996 secs...
# Extracting EDF parameters from /scratch/agjma/tuh_selected/aaaaaado_s004_t002.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 79999  =      0.000 ...   199.998 secs...

# %%
raw.info
# Out:
# <Info | 8 non-empty values
#  bads: []
#  ch_names: EEG FP1-REF, EEG FP2-REF, EEG F3-REF, EEG F4-REF, EEG C3-REF, ...
#  chs: 27 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 125.0 Hz
#  meas_date: 2012-03-30 13:19:10 UTC
#  nchan: 27
#  projs: []
#  sfreq: 250.0 Hz
#  subject_info: 3 items (dict)
# >

# %%
annot_df = load_tuev_annotation(raw_edf_file_path)
annot_df.head(40)
# Out:
#     start    end event
# 0     9.1   10.1  eyem
# 1     9.2   10.2  eyem
# 2    56.1   57.1  eyem
# 3    57.5   58.5  eyem
# 4    58.9   59.9  eyem
# 5    59.0   60.0  eyem
# 6   118.3  119.3  eyem
# 7   119.2  120.2  eyem
# 8   119.3  120.3  eyem
# 9   120.2  121.2  eyem
# 10  120.3  121.3  eyem
# 11  121.2  122.2  eyem
# 12  121.3  122.3  eyem
# 13  122.2  123.2  eyem
# 14  131.4  132.4  eyem
# 15  131.5  132.5  eyem
# 16  131.6  132.6  eyem
# 17  132.4  133.4  eyem
# 18  132.5  133.5  eyem
# 19  132.6  133.6  eyem
# 20  133.4  134.4  eyem
# 21  133.5  134.5  eyem
# 22  133.6  134.6  eyem
# 23  134.4  135.4  eyem
# 24  134.5  135.5  eyem
# 25  134.6  135.6  eyem
# 26  135.4  136.4  eyem
# 27  135.5  136.5  eyem
# 28  135.6  136.6  eyem
# 29  136.4  137.4  eyem
# 30  136.5  137.5  eyem
# 31  136.6  137.6  eyem
# 32  137.4  138.4  eyem
# 33  137.5  138.5  eyem
# 34  137.6  138.6  eyem
# 35  138.4  139.4  eyem
# 36  138.5  139.5  eyem
# 37  138.6  139.6  eyem
# 38  139.4  140.4  eyem
# ...

# %%
annot_df
# Out:
#     start   end event
# 0     0.4   1.4  bckg
# 1     1.4   2.4  bckg
# 2     2.4   3.4  bckg
# 3     3.4   4.4  bckg
# 4     4.4   5.4  bckg
# 5     5.4   6.4  bckg
# 6     6.4   7.4  bckg
# 7     7.4   8.4  bckg
# 8     8.4   9.4  bckg
# 9    68.3  69.3  bckg
# 10   69.3  70.3  bckg
# 11   70.3  71.3  bckg
# 12   71.3  72.3  bckg
# 13   72.3  73.3  bckg
# 14   73.3  74.3  bckg
# 15   74.3  75.3  bckg
# 16   75.3  76.3  bckg
# 17   76.3  77.3  bckg

# %%
TUEV_dir_path = "/nobackup/tsal-tmp/tuh_eeg_events/v2.0.0/edf/train/"

TUEV_files = glob(TUEV_dir_path + "*/*.edf")
print(f"{len(TUEV_files)=}")
# Out:
# len(TUEV_files)=359

# %%
# raw.info
# TUEV_files

# %%
return_raw = process_TUEV_edf(raw_edf_file_path)
# Out:
# Overwriting existing file.

# %%
return_raw.annotations[0]
# Out:
# OrderedDict([('onset', 0.4),
#              ('duration', 0.9999999999999999),
#              ('description', 'bckg'),
#              ('orig_time',
#               datetime.datetime(2013, 4, 26, 9, 49, 27, tzinfo=datetime.timezone.utc))])

# %%
raw.ch_names
# raw_tuh_selected.ch_names
# Out:
# ['EEG FP1-REF',
#  'EEG FP2-REF',
#  'EEG F3-REF',
#  'EEG F4-REF',
#  'EEG C3-REF',
#  'EEG C4-REF',
#  'EEG P3-REF',
#  'EEG P4-REF',
#  'EEG O1-REF',
#  'EEG O2-REF',
#  'EEG F7-REF',
#  'EEG F8-REF',
#  'EEG T3-REF',
#  'EEG T4-REF',
#  'EEG T5-REF',
#  'EEG T6-REF',
#  'EEG T1-REF',
#  'EEG T2-REF',
#  'EEG FZ-REF',
#  'EEG CZ-REF',
#  'EEG PZ-REF',
#  'EEG EKG1-REF',
#  'EEG C3P-REF',
#  'EEG C4P-REF',
#  'EEG SP1-REF',
#  'EEG SP2-REF',
#  'EMG-REF',
#  'EEG A1-REF',
#  'EEG A2-REF',
#  'EEG 31-REF',
#  'EEG 32-REF']

# %%
annot_df = load_tuev_annotation(raw_edf_file_path, use_montage_20=False)
annot_df
# Out:
#     start   end event
# 0     0.4   1.4  bckg
# 1     1.4   2.4  bckg
# 2     2.4   3.4  bckg
# 3     3.4   4.4  bckg
# 4     4.4   5.4  bckg
# 5     5.4   6.4  bckg
# 6     6.4   7.4  bckg
# 7     7.4   8.4  bckg
# 8     8.4   9.4  bckg
# 9    68.3  69.3  bckg
# 10   69.3  70.3  bckg
# 11   70.3  71.3  bckg
# 12   71.3  72.3  bckg
# 13   72.3  73.3  bckg
# 14   73.3  74.3  bckg
# 15   74.3  75.3  bckg
# 16   75.3  76.3  bckg
# 17   76.3  77.3  bckg

# %%
# map ch_idx to ch_name
ch_idx_name_map = {
    0: "EEG FP1-REF",
    1: "EEG F7-REF",
    2: "EEG T3-REF",
    3: "EEG T5-REF",
    4: "EEG FP2-REF",
    5: "EEG F8-REF",
    6: "EEG T4-REF",
    7: "EEG T6-REF",
    8: "EEG A1-REF",
    9: "EEG T3-REF",
    10: "EEG C3-REF",
    11: "EEG CZ-REF",
    12: "EEG C4-REF",
    13: "EEG T4-REF",
    14: "EEG FP1-REF",
    15: "EEG F3-REF",
    16: "EEG C3-REF",
    17: "EEG P3-REF",
    18: "EEG FP2-REF",
    19: "EEG F4-REF",
    20: "EEG C4-REF",
    21: "EEG P4-REF",
    }

# %%
sorted(annot_df["ch_idx"].unique())

# %%
# plot the raw data with annotations between 0 and 100 seconds
raw.plot()

# %%
process_TUEV_edf(raw_edf_file_path, save_dir="/scratch/s194101/TUEV_processed/", verbose=True)

# %%
TUEV_dir_path = "/nobackup/tsal-tmp/tuh_eeg_events/v2.0.0/edf/train/"

# %% [markdown]
# # read mmidb file as test

# %%
mne_file_path = "/scratch/agjma/eegmmidb/files/S001/S001R03.edf"

mne_raw = mne.io.read_raw_edf(mne_file_path, preload=True)

mne_raw.annotations

# %%
mne_raw.annotations[3]

# %%
mne_raw.ch_names

# %%
temp = read_TUH_edf(raw_edf_file_path)

# %%
temp.ch_names
