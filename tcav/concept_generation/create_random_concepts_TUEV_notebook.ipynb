# %%
import mne
import numpy as np

import os

from glob import glob
from tqdm import tqdm
from utils import read_TUH_edf
import pickle
import torch

# %%
# TUEV_dir_path = "/nobackup/tsal-tmp/tuh_eeg_events/v2.0.0/edf/eval/"
TUEV_dir_path = "/nobackup/tsal-tmp/tuh_eeg_events/v2.0.0/edf/train/"

edf_files = glob(f"{TUEV_dir_path}/*/*.edf")
print(f"total files: {len(edf_files)}")
# Out:
# total files: 359

# %%
def process_file(filepath, save_dir, n_samples=2, sample_length=60):
    channel_order = [
                'Fp1', 'Fp2',
        'F7', 'F3', 'Fz', 'F4', 'F8',
        'T3', 'C3', 'Cz', 'C4', 'T4',
        'T5', 'P3', 'Pz', 'P4', 'T6',
                 'O1', 'O2'
    ]
    raw = read_TUH_edf(filepath)
    try:
        raw.pick_channels(channel_order)
        raw.reorder_channels(channel_order)
    except:
        print("Error in picking and reordering channels")
        return

    sample_freq = raw.info['sfreq'] # 256
    for i in range(n_samples):
        start = np.random.randint(0, raw.n_times - sample_length * sample_freq)
        length = int(sample_length * sample_freq)


        sample = raw.copy().get_data()[:, start:start + length]

        x = torch.from_numpy(sample)

        if x.shape[0] != 19: # needs to be 19 channels
            print(f"Skipping {filepath} because of shape {x.shape}")
            continue

        # save as pickle file
        save_path = os.path.join(save_dir, os.path.basename(filepath).replace(".edf", f"_sample_{i}.pkl"))
        with open(save_path, 'wb') as f:
            pickle.dump(x, f, protocol=pickle.HIGHEST_PROTOCOL)

# %%
for filepath in tqdm(edf_files):
    channel_order = [
                'Fp1', 'Fp2',
        'F7', 'F3', 'Fz', 'F4', 'F8',
        'T3', 'C3', 'Cz', 'C4', 'T4',
        'T5', 'P3', 'Pz', 'P4', 'T6',
                 'O1', 'O2'
    ]
    raw = read_TUH_edf(filepath)
    try:
        raw.pick_channels(channel_order)
        raw.reorder_channels(channel_order)
    except:
        continue

    sample_freq = raw.info['sfreq'] # 256
    for i in range(n_samples):
        start = np.random.randint(0, raw.n_times - sample_length * sample_freq)
        length = int(sample_length * sample_freq)


        sample = raw.copy().get_data()[:, start:start + length]



    break
# Out:
#   0%|          | 0/359 [00:00<?, ?it/s]
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
#   0%|          | 0/359 [00:03<?, ?it/s]

# %%
raw
# Out:
# <RawEDF | 00001940_00000001.edf, 21 x 313088 (1223.0 s), ~50.2 MB, data loaded>
